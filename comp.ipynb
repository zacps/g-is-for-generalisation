# %%
import pickle
import pandas as pd
import numpy as np

# %%
with open('good.pickle', 'rb') as f:
    good = pickle.load(f)
with open('bad.pickle', 'rb') as f:
    bad = pickle.load(f)

# %%
good = good.sort_index(); good
# Out:
#          focus_gained  focus_lost    run  submit  text_insert  text_paste  \
# student
# 0               335.0       327.0   94.0    30.0       4744.0        59.0
# 1               327.0       325.0  205.0    37.0       7050.0        45.0
# 2               711.0       672.0  161.0    31.0       4660.0        80.0
# 3               100.0        89.0    0.0    30.0        284.0        28.0
# 4               311.0       310.0   82.0    39.0       4552.0        20.0
# ...               ...         ...    ...     ...          ...         ...
# 444             168.0       166.0   74.0    31.0       5559.0         1.0
# 445             507.0       448.0  213.0    30.0      16526.0         2.0
# 446             369.0       365.0  131.0    32.0       4122.0       114.0
# 447             359.0       336.0  129.0    30.0       5635.0        96.0
# 448             153.0       139.0   12.0    39.0       3597.0        42.0
#
#          text_remove  time_to_last  time_to_first       duration  \
# ...

# %%
bad
# Out:
#          focus_gained  focus_lost    run  submit  text_insert  text_paste  \
# student
# 0               335.0       327.0   94.0    30.0       4744.0        59.0
# 1               327.0       325.0  205.0    37.0       7050.0        45.0
# 2               711.0       672.0  161.0    31.0       4660.0        80.0
# 3               100.0        89.0    0.0    30.0        284.0        28.0
# 4               311.0       310.0   82.0    39.0       4552.0        20.0
# ...               ...         ...    ...     ...          ...         ...
# 444             168.0       166.0   74.0    31.0       5559.0         1.0
# 445             507.0       448.0  213.0    30.0      16526.0         2.0
# 446             369.0       365.0  131.0    32.0       4122.0       114.0
# 447             359.0       336.0  129.0    30.0       5635.0        96.0
# 448             153.0       139.0   12.0    39.0       3597.0        42.0
#
#          text_remove  time_to_last  time_to_first       duration  \
# ...

# %%
(good.sort_index().index == bad.index).all()
# Out:
# True

# %%
(good==bad).all(axis=0)
# Out:
# focus_gained           True
# focus_lost             True
# run                    True
# submit                 True
# text_insert            True
# text_paste             True
# text_remove            True
# time_to_last           True
# time_to_first          True
# duration               True
# coarse_time_on_task    True
# fine_time_on_task      True
# mean_latency           True
# dtype: bool

# %%
with open('good_grades.pickle', 'rb') as f:
    good = pickle.load(f)
with open('bad_grades.pickle', 'rb') as f:
    bad = pickle.load(f)

# %%
(good == bad).all()
# Out:
# part1    True
# part2    True
# part3    True
# part4    True
# part5    True
# part6    True
# part7    True
# exam1    True
# exam2    True
# exam3    True
# final    True
# dtype: bool
